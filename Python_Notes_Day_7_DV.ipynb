# %% [markdown]
# <a href="https://colab.research.google.com/github/kalashjain9/Python-Notes/blob/main/Python_Notes_Day_7_DV.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # ***Matplotlib: Your Artistic Brush for Data***
#
# Welcome to the world of Matplotlib! Imagine you have a canvas, and your data points are the paints. Matplotlib is the set of brushes, colors, and techniques that allow you to transform raw data into beautiful, insightful, and understandable visual masterpieces.
#
# # ***Why is visualization so important?***
# Think about trying to understand a complex story just by reading a list of every single word in it. It would be incredibly difficult, right? But if you saw a picture or a movie, the story would come alive. Data is similar. Raw numbers can be overwhelming, but when visualized, patterns, trends, and outliers pop out, making complex information digestible and actionable.
#
# Matplotlib is a powerful and widely used Python library for creating static, animated, and interactive visualizations. It’s the foundation for many other visualization libraries and is incredibly versatile, allowing you to create almost any type of plot you can imagine.

# %% [markdown]
# # ***The Indispensable Need for Matplotlib: Real-Life Scenarios***
#
# Imagine trying to understand complex data by just looking at raw numbers in a spreadsheet. It's like trying to understand a novel by just reading the dictionary. Matplotlib transforms these raw numbers into intuitive, actionable insights. Here's why it's crucial, with diverse real-life examples:
#
# # ***1. Understanding Location and Movement (GPS Coordinates)***
# ***Scenario***: A logistics company tracks the delivery routes of its fleet of trucks using GPS. They have a massive dataset of latitude and longitude points collected every few seconds for hundreds of trucks over days.
#
# ##***The Problem Without Matplotlib***:
#
# ***Overwhelming Data***: Thousands, if millions, of coordinate pairs (e.g., (19.234, 72.856), (19.235, 72.857), ...) are impossible to process mentally.
#
# **Hidden Inefficiencies**: You can't tell if a truck took an optimal route, made unnecessary detours, or got stuck in traffic. Are there common bottlenecks? Are drivers making unauthorized stops?
#
# **No Quick Insights**: To answer questions like "Which trucks deviated from their planned route today?" or "Where was truck A at 2 PM?", you'd need to manually search and compare coordinate lists – a nearly impossible task.
#
# # ***The Need for Matplotlib***:
#
# **Visualizing Routes (Line Plots/Scatter Plots)**: Matplotlib can plot these GPS coordinates as a series of connected points (plt.plot) or individual dots (plt.scatter) on a map-like background.
#
# **Example**: Plotting truck_id, latitude, longitude, timestamp.
#
# **What it reveals**: Immediately shows the actual path taken by each truck. You can quickly spot deviations, long stops (where points are clustered), or areas of slow movement.

# %%
pip install matplotlib

# %% [markdown]
# # ***1. Tracking Your Fitness/Health:***
#
# **Data**: Daily steps, heart rate, sleep hours, calories burned (from your smartwatch or fitness tracker).
#
# **Why Matplotlib?** You can plot Daily Steps over Date as a line graph to see if you're consistently active, or create a bar chart of Sleep Hours by Day of the Week to identify if your sleep schedule is irregular. You can even combine Calories Burned and Calories Consumed on one plot to manage your diet.
#
# # ***2. Analyzing Electricity Bills:***
#
# **Data**: Monthly electricity consumption (units), bill amount, temperature.
#
# **Why Matplotlib?** Plot Units Consumed and Bill Amount side-by-side as bar charts for each month to see how your usage impacts costs. You could even scatter plot Temperature vs. Units Consumed to understand how much your AC or heater affects your bill.
#
# # ***3. Comparing Phone Plans:***
#
# **Data**: Different phone plans' data limits, call minutes, SMS, and monthly costs.
#
# **Why Matplotlib?** Create a bar chart comparing Monthly Cost for various plans. You could use a grouped bar chart to compare Data, Calls, and SMS allowances across two or three plans to see which offers the best value for your typical usage.

# %% [markdown]
# # ***4. Weather Analysis (Local Level):***
#
# **Data**: Daily temperature, rainfall, humidity for your city over a year.
#
# **Why Matplotlib?** A line graph of Daily Temperature reveals seasonal variations and extreme heat/cold days. A bar chart of Monthly Rainfall helps understand wet and dry seasons. A scatter plot of Temperature vs. Humidity can show how comfortable or muggy different days feel.
#
# # ***5. Monitoring Home Energy Usage (Smart Homes):***
#
# **Data**: Hourly energy consumption from smart plugs for appliances (fridge, TV, AC).
#
# **Why Matplotlib?** Plot Energy Consumption (kWh) for each appliance over Hour of Day. This instantly shows when your fridge is most active, or if your TV is drawing power even when off. This helps you identify energy vampires and save money.
#
# # ***6. Personal Finance Tracking:***
#
# **Data**: Monthly income, expenses (rent, food, entertainment), savings.
#
# **Why Matplotlib?** A stacked bar chart showing Income vs. different Expense Categories helps you visualize where your money goes. A line graph of Savings over Months helps you track financial goals. A pie chart can show the proportion of your budget spent on each category.
#
# # ***7. Analyzing Website Traffic:***
#
# **Data**: Daily website visitors, bounce rate, average time on page.
#
# **Why Matplotlib?** Plot Website Visitors over Date to see traffic trends, or a scatter plot of Time on Page vs. Bounce Rate to understand user engagement. This helps website owners improve their site.

# %% [markdown]
# # ***Terminology Explanation of Matplotlib Library:***
#
# Understanding these terms will help you navigate the Matplotlib documentation and communicate effectively about your visualizations.

# %% [markdown]
# # ***1. Figure (`Figure` object)***:
# The entire window or page that contains your plot(s). Think of it as the blank canvas or piece of paper on which you will draw. You can have multiple subplots within a single figure.
#
# **Real-Life Example**: A physical drawing board or a sheet of paper.
#
# Why is this needed?
#
# **Organization**: You might want to create a report with several related graphs (e.g., sales trends by region). The Figure acts as the container for all these graphs, keeping them together. Without it, each plot would open in its own separate window, making comparison difficult.
#
# **Saving Output**: When you save a plot to a file (like PNG or PDF), you're saving the entire Figure. If you want to save a collection of charts as a single image file, you need one Figure to hold them.
#
# **Global Customization**: You can set global properties for all plots within a figure, like its overall size (figsize) or background color.

# %%
import matplotlib.pyplot as plt
fig = plt.figure(figsize=(10, 6)) # Create a new figure with specific dimensions
# All subsequent plots added will live within this figure until it's closed
plt.show()

# %% [markdown]
# # ***2. Axes (`Axes` object)***:
# Not to be confused with the plural of "axis." An Axes object is where the data is actually plotted. It's the region of the image with the data space (e.g., the part with the x-axis, y-axis, and data points). A figure can contain multiple Axes.
#
# **Real-Life Example:** The individual graphs you draw on that drawing board. Each graph has its own X and Y axes.
#
# **Why is this needed?**
#
# **Independent Plots**: If you want to show a bar chart of product sales and a line chart of website traffic on the same page but as separate graphs, you need two distinct Axes objects within one Figure. Each Axes is an independent plotting area.
#
# **Fine-grained Control**: Many customization options (titles, labels, limits, ticks) are specific to an individual Axes. You can set a title for ax1 and a different title for ax2 if you have multiple plots.
#
# **Layering**: You can draw multiple lines, scatter points, etc., on the same Axes object to compare them directly.

# %%
import matplotlib.pyplot as plt
fig, ax = plt.subplots() # Creates a figure AND a single axes object
ax.plot([1, 2, 3], [4, 5, 6]) # We plot *on* the axes object
ax.set_title('My Plot on an Axes')
plt.show()

# %% [markdown]
# # ***3. Axis (`Axis` object):***
# Refers to the number line-like objects (e.g., X-axis, Y-axis). They handle setting the plot limits (min/max values), generating ticks (the marks on the axis), and tick labels (the numbers/text next to the ticks).
#
# **Real-Life Example**: The numbered lines (e.g., horizontal for time, vertical for temperature) that define the scales of your graph.
#
# **Why is this needed?**
#
# **Readability**: Without axes, your data points would just float in space without context. Axes provide the scale and units, allowing viewers to understand the values.
#
# **Control over Scale**: You can set specific limits (xlim, ylim) for your axes to zoom in on a particular data range or ensure consistency across multiple plots.
#
# **Custom Labels and Formatting**: You might want to display dates on the x-axis instead of raw numbers, or format currency values on the y-axis. Axis objects allow for such precise labeling and formatting.
#
# **Categorical Data**: For bar charts, the Axis handles placing the categorical labels (e.g., "Apples", "Bananas") correctly.

# %%
import matplotlib.pyplot as plt
fig, ax = plt.subplots()
ax.plot([1, 2, 3], [4, 5, 6])
ax.set_xlim(0, 4) # Set x-axis limits from 0 to 4
ax.set_ylim(3, 7) # Set y-axis limits from 3 to 7
ax.set_xticks([1, 2, 3]) # Explicitly set x-axis ticks
ax.set_xticklabels(['Group A', 'Group B', 'Group C']) # Set custom labels for ticks
plt.show()

# %% [markdown]
# # ***4. Backend***:
# Matplotlib can draw to many different output formats. The backend is the code that handles this drawing. Examples include 'TkAgg' (for interactive windows), 'Agg' (for static PNG images), 'SVG' (for scalable vector graphics), etc. You usually don't interact with this directly unless troubleshooting.
#
# **Real-Life Example:** The specific type of pen or printer you're using to make your drawing (e.g., a ballpoint pen, a marker, an inkjet printer).
#
# **Why is this needed?**
#
# **Flexibility in Output**: You might develop your plots interactively on your computer, but then need to save them as high-quality images for a presentation or web page. Different backends cater to these different needs (interactive vs. static file export).
#
# **Server Environments**: When running Python code on a server without a graphical interface, you need a non-interactive backend (like 'Agg') to generate image files without trying to open a window, which would cause an error.
#
# **Performance/Features**: Some backends might be faster for certain types of operations, or support specific interactive features.
#
# # ***Code Example (Setting backend, usually not needed for basic plotting):***

# %%
pip install matplotlib

# %%
import matplotlib
matplotlib.use('Agg') # Set backend to 'Agg' for non-interactive plotting (e.g., saving to file)
import matplotlib.pyplot as plt
fig, ax = plt.subplots()
ax.plot([1, 2], [3, 4])
fig.savefig('my_plot.png') # This will save without opening a window
# Now, if you try plt.show(), it might not do anything depending on the backend, or error out.

# %% [markdown]
# # ***5. Artist***:
# Everything visible on the Figure is an Artist. This includes Figure, Axes, and Axis objects, as well as text (titles, labels), lines, patches (like bars in a bar chart), images, etc. When you call a plotting function, you're creating Artist objects.
#
# **Real-Life Example**: Every single drawn element on your paper – a line, a curve, a label, a title, a bar.
#
# **Why is this needed?**
#
# **Building Blocks**: Artists are the fundamental components of any Matplotlib plot. Understanding them allows you to manipulate any visual element precisely.
#
# **Advanced Customization**: If you want to change a specific property of a line after it's drawn (e.g., its color, thickness, or add an arrow to it), you interact with the Line2D Artist object directly.
#
# **Programmatic Control**: For complex or highly customized plots, you often work directly with Artist objects to build your visualization step-by-step.

# %%
import matplotlib.pyplot as plt
line, = plt.plot([1, 2, 3], [4, 5, 6]) # plt.plot returns a list, we unpack the first element
print(f"Type of 'line' object: {type(line)}") # This is a Line2D Artist
line.set_color('green') # Modify the color property of the line Artist
line.set_linewidth(3) # Modify its thickness

title_artist = plt.title('Dynamic Title') # The title itself is a Text Artist
title_artist.set_fontsize(16) # Change the font size of the title

plt.show()
# Out:
# Type of 'line' object: <class 'matplotlib.lines.Line2D'>

# %% [markdown]
# # ***6. Subplot***:
# A plot within a larger figure. Matplotlib allows you to create grids of plots (e.g., a 2x2 grid with four separate graphs). Each individual graph in this grid is a subplot.
#
# **Real-Life Example**: Having multiple smaller frames within a single larger frame, each containing a different picture.
#
# **Why is this needed?**
#
# **Comparison**: To visually compare multiple datasets or different aspects of the same data side-by-side. For instance, comparing sales over time for different products or showing a histogram alongside a scatter plot of related data.
#
# **Storytelling**: A single figure with multiple, related subplots can tell a much richer data story than individual plots. For example, showing a company's revenue growth, profit margin, and customer acquisition all on one page.
#
# **Efficient Space Usage**: Instead of having many separate image files or windows, subplots allow you to consolidate information efficiently.

# %%
import matplotlib.pyplot as plt
# Creates a figure with a 2x1 grid of subplots (2 rows, 1 column)
fig, (ax1, ax2) = plt.subplots(2, 1, figsize=(8, 8))

ax1.plot([1, 2, 3], [4, 5, 6], color='blue')
ax1.set_title('Temperature Trend')

ax2.bar(['A', 'B', 'C'], [5, 7, 3], color='green')
ax2.set_title('Product Sales')

plt.tight_layout() # Adjusts subplot params for a tight layout
plt.show()

# %% [markdown]
# # ***7. `pyplot (plt)`***:
# A module within Matplotlib that provides a MATLAB-like interface for plotting. It's designed to make interactive plotting as simple as possible. It automatically creates figures and axes when needed, making it very user-friendly for quick plots. Most of our examples use plt.
#
# **Real-Life Example**: A friendly assistant who takes your instructions (plot this, add a title) and automatically sets up the drawing board and drawing tools for you.
#
# **Why is this needed?**
#
# **Simplicity for Beginners:** For common, simple plots, pyplot significantly reduces the boilerplate code needed. You don't always need to explicitly create Figure and Axes objects.
#
# **Quick Exploratory Data Analysis**: When you just want to quickly visualize some data to get a sense of it, pyplot allows for rapid prototyping.
#
# **Compatibility**: Its MATLAB-like syntax makes it familiar for users coming from that environment.

# %%
import matplotlib.pyplot as plt

# This plots a simple line graph
plt.plot([1, 2, 3], [10, 20, 15])       # Line from points (1,10), (2,20), (3,15)
plt.xlabel('Experiment Number')        # Label for X-axis
plt.ylabel('Result')                   # Label for Y-axis
plt.title('Quick Experiment Results')  # Title of the graph
plt.show()                             # Display the graph

# %% [markdown]
# # ***8. Marker***:
# A symbol used to denote individual data points on a plot, especially in line or scatter plots. Examples include circles ('**o**'), squares ('**s**'), triangles ('**^**'), or crosses ('**x**').
#
# **Real-Life Example**: The specific shape you use to mark where each data point is on your graph, like a small dot or a tiny star.
#
# **Why is this needed?**
#
# **Clarity of Data Points**: In a line chart, markers clearly show where your actual data points are, distinguishing them from the interpolated line.
#
# **Distinguishing Series**: When plotting multiple lines or series, using different marker types for each can help differentiate them even if colors are similar or unavailable (e.g., in black-and-white printing).
#
# **Specific Meaning**: A circle might represent an observed value, while an 'X' might represent a prediction. Markers can encode additional information.

# %%
import matplotlib.pyplot as plt
days = [1, 2, 3, 4, 5]
sales = [10, 12, 9, 15, 11]
plt.plot(days, sales, marker='^', markersize=8, color='blue') # Triangular markers
plt.scatter(days, sales, marker='s', s=100, color='red') # Square markers in scatter plot
plt.show()

# %% [markdown]
# # ***9. Line Style (`linestyle`)***:
# The pattern of the line connecting data points in a line plot. Common styles include solid **('-'),** dashed **('--'),** dotted **(':'),** and dash-dot **('-.').**
#
# **Real-Life Example**: Whether you draw a continuous line, a dashed line, or a dotted line on your graph.
#
# **Why is this needed?**
#
# **Differentiating Lines**: Similar to markers, different line styles are crucial for distinguishing multiple lines on the same plot, especially when color printing isn't an option or colors are hard to discern. For example, solid for actual data, dashed for a forecast.
#
# **Conveying Meaning**: A dashed line might imply an estimate or a projected trend, while a solid line indicates confirmed data.
#
# **Aesthetics**: Different line styles can simply make the plot look more professional or easier on the eyes.

# %%
import matplotlib.pyplot as plt
x = [1, 2, 3, 4]
y1 = [10, 12, 15, 13]
y2 = [8, 11, 14, 16]
plt.plot(x, y1, linestyle='-', label='Actual') # Solid line
plt.plot(x, y2, linestyle='--', label='Forecast') # Dashed line
plt.legend()
plt.show()

# %% [markdown]
# # ***10. Colormap (`cmap`)***:
# A mapping of data values to colors. Used for plots where color represents a third variable (e.g., in heatmaps, or scatter plots where point color indicates a value).
#
# **Real-Life Example**: A key that tells you what shades of color correspond to different temperatures on a weather map (e.g., dark blue for cold, red for hot).
#
# **Why is this needed?**
#
# **Visualizing High Dimensions**: When you have more than two variables, colormaps allow you to encode a third (or even fourth, with marker size) variable's value using color intensity or hue. This is critical for plots like heatmaps (e.g., temperature distribution across a surface) or scientific visualizations.
#
# **Quantitative Representation:** Instead of just showing categories, colormaps allow the color itself to convey a numerical value. Lighter shades for lower values, darker for higher, or a spectrum from cold to hot colors.
#
# **Better Insight**: Helps identify patterns or relationships that might not be apparent from just two dimensions. For instance, in a scatter plot of height vs. weight, coloring points by age can reveal age-related clusters.
#
# # ***Code Example (Conceptual, more often used with imshow or advanced scatter plots):***

# %%
# Import the pyplot module from matplotlib for plotting
import matplotlib.pyplot as plt

# Import numpy for generating and manipulating numerical data
import numpy as np

# Set a random seed so the random numbers are reproducible (same every time you run)
np.random.seed(42)

# Generate 50 random X-coordinates between 0 and 10
x = np.random.rand(50) * 10

# Generate 50 random Y-coordinates between 0 and 10
y = np.random.rand(50) * 10

# Create a third variable 'values' that depends on x and y with added Gaussian noise
# This simulates some measurement or value increasing with x and y
values = x + y + np.random.randn(50) *2

# Create a scatter plot of x and y
# - c=values: color of each point based on 'values'
# - cmap='viridis': use the 'viridis' color map
# - s=100: size of each point
# - alpha=0.8: transparency of points (1.0 is fully opaque)
plt.scatter(x, y, c=values, cmap='viridis', s=100, alpha=0.5)

# Add a color bar on the side to show the mapping of color to 'values'
plt.colorbar(label='Measurement Value')

# Set the title of the plot
plt.title('Data Points Colored by a Third Variable')

# Label the X-axis
plt.xlabel('X-coordinate')

# Label the Y-axis
plt.ylabel('Y-coordinate')

# Display the final plot
plt.show()

# %% [markdown]
# # ***11. Grid***:
# A network of horizontal and vertical lines on a plot that aids in reading values and aligning points.
#
# **Real-Life Example**: The faint lines on graph paper that help you plot points accurately.
#
# **Why is this needed?**
#
# **Precision Reading**: Helps users estimate exact values for data points more easily, especially when looking at multiple points. You can quickly see that a point aligns with, say, "150" on the Y-axis.
#
# **Comparison Across Axes**: Makes it easier to compare the relative positions of points on different parts of the plot.
#
# **Professionalism:** A well-placed, subtle grid often makes a plot look more polished and easier to interpret.

# %%
import matplotlib.pyplot as plt
plt.plot([1, 2, 3], [4, 5, 6])
plt.grid(True) # Adds a default grid
plt.grid(axis='x', linestyle=':', color='gray', alpha=0.5) # Customize only x-axis grid
plt.show()

# %%
import matplotlib.pyplot as plt
plt.plot([1, 2, 3], [4, 5, 6])
plt.grid(True) # Adds a default grid
plt.grid(axis='both', linestyle=':', color='gray', alpha=0.5) # Customize only x-axis grid
plt.show()

# %% [markdown]
# # ***12. Tick & Tick Label:***
#
# **Tick**: The small marks on the axes that indicate specific values.
#
# **Tick Label**: The text or number next to each tick, indicating the value.
#
# **Real-Life Example**: On a ruler, the little lines are the ticks, and the numbers (1, 2, 3) next to them are the tick labels.
#
# **Why is this needed?**
#
# **Quantifying Data**: Ticks and labels provide the actual numerical or categorical values that correspond to positions on the axis, making the plot quantifiable. Without them, you wouldn't know what "5" or "Monday" means on the scale.
#
# **Readability & Granularity**: You can control the density of ticks (e.g., show every 10 units vs. every 100 units) and their formatting (e.g., currency, dates, percentages) to improve readability and ensure the plot is not too cluttered or too sparse.
#
# **Contextual Information**: Tick labels provide critical context. Is it temperature in Celsius, or dollars, or number of units? The label tells you.

# %%
import matplotlib.pyplot as plt
import numpy as np
months = ['Jan', 'Feb', 'Mar', 'Apr', 'May']
sales = [100, 120, 110, 140, 130]

plt.plot(months, sales)
plt.xlabel('Month')
plt.ylabel('Sales ($)')
plt.yticks(np.arange(80, 151, 10)) # Set y-ticks from 80 to 150, every 10 units
plt.show()

# %% [markdown]
# # ***Summary***

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# # ***Introduction to Data Visualization***
#
# Data visualization is like drawing pictures to tell stories with numbers. Instead of just looking at long lists of data, we create charts and graphs to see patterns, trends, and insights quickly. Imagine trying to understand a city's traffic just by reading a list of car counts every minute – it would be confusing! But if you saw a graph showing traffic peaks and dips, you'd understand it instantly. That's the power of visualization!
#
# In this chapter, we'll be using a fantastic Python library called Matplotlib. Think of Matplotlib as our digital canvas and a set of drawing tools that allows us to create all sorts of plots and charts.
#
# # ***Basic Plots: Our Essential Drawing Tools***
#
# We'll start with five fundamental types of plots that are incredibly useful for different kinds of data.

# %% [markdown]
# # ***1. Histogram: Understanding Distributions***
#
# A histogram is like sorting items into bins and then counting how many items fall into each bin. It helps us understand the distribution of a single numerical variable. For example, if you want to see how many students scored in different ranges on a test (0-20, 21-40, etc.), a histogram is perfect.
#
# **Real-Life Scenario**: Imagine you own a clothing store and want to understand the most common age groups of your customers.
#
# **Matplotlib Function**: **`plt.hist(data)`**
#
# **Parameters**:
#
# **`data`**: This is a list or array of numerical values for which you want to see the distribution.

# %% [markdown]
# **Examples**:
#
# # ***Example 1 :- Basic Age Distribution***
#
# **Scenario**: You collected the ages of 20 customers. You want to see the general age distribution.

# %%
import matplotlib.pyplot as plt # Import the Matplotlib library for plotting
import numpy as np # Import NumPy for numerical operations (useful for creating data)

# Customer ages collected from a survey
customer_ages = [22, 25, 30, 35, 28, 40, 25, 22, 30, 45, 50, 35, 28, 25, 30, 22, 40, 38, 32, 25]

plt.hist(customer_ages) # Create a histogram of the customer_ages data
plt.title("Distribution of Customer Ages") # Set the title of the plot
plt.xlabel("Age Group") # Label for the horizontal axis (what the data represents)
plt.ylabel("Number of Customers") # Label for the vertical axis (how many items in each bin)
plt.show() # Display the plot

# %% [markdown]
# * **import matplotlib.pyplot as plt**: This line imports the pyplot module from the matplotlib library. We commonly use plt as an alias for matplotlib.pyplot to make our code shorter and easier to read. It's like calling your friend "Alex" instead of "Alexander."
#
# * **import numpy as np**: We import NumPy, which is a powerful library for numerical computing in Python. While not strictly necessary for this very basic example, it's often used with Matplotlib for data generation and manipulation.
#
# * **customer_ages = [...]**: This creates a list called customer_ages containing the ages of different customers. This is our raw data.
#
# * **plt.hist(customer_ages)**: This is the core command! It tells Matplotlib to take the customer_ages data and draw a histogram. Matplotlib automatically decides how to group the ages into "bins" (e.g., 20-25, 26-30, etc.) and then counts how many ages fall into each bin.
#
# * **plt.title(...), plt.xlabel(...), plt.ylabel(...)**: These lines add important labels to our plot. A good plot always has a clear title and labels for its axes so that anyone looking at it knows exactly what they are seeing.
#
# * **plt.show()**: This command displays the plot. Without plt.show(), the plot might be generated in the background but won't appear on your screen.

# %% [markdown]
# # ***Example 2: Exam Score Distribution with More Bins***
#
# **Scenario**: A teacher wants to see how the scores of 100 students are distributed in an exam (scores from 0 to 100). They want to see more detailed bins (e.g., in groups of 10 marks).

# %%
import matplotlib.pyplot as plt
import numpy as np

# Generating 100 random exam scores between 40 and 100
#exam_scores = [ 99, 75 ,.......]
exam_scores = np.random.randint(40, 101, 100) # Creates an array of 100 random integers between 40 and 100

# Define the bins for the histogram (e.g., 0-10, 11-20, ..., 91-100)
bins = range(0, 101, 10) # Creates a sequence of numbers from 0 to 100 with a step of 10

plt.hist(exam_scores, bins=bins, edgecolor='black') # Create histogram with custom bins and black edges
plt.title("Distribution of Exam Scores")
plt.xlabel("Score Range")
plt.ylabel("Number of Students")
plt.xticks(bins) # Set x-axis ticks to match the bin edges for clarity
plt.grid(axis='y', alpha=0.75) # Add a horizontal grid for better readability
plt.show()

# %% [markdown]
# * **np.random.randint(40, 101, 100)**: This uses NumPy to generate 100 random integer scores. The scores will be between 40 (inclusive) and 101 (exclusive), so effectively 40 to 100.
#
# * **bins = range(0, 101, 10)**: This creates a range object that will be used to define the boundaries of our histogram bins. It will create bins like [0, 10), [10, 20), etc., up to [90, 100].
#
# * **plt.hist(exam_scores, bins=bins, edgecolor='black')**: Here, we pass our bins variable to the bins parameter of plt.hist(). This gives us fine-grained control over how the data is grouped. edgecolor='black' adds a black border to each bar, making them stand out.
#
# * **plt.xticks(bins)**: This ensures that the labels on the x-axis (score ranges) are exactly where our bins start and end, making the plot very clear.
#
# * **plt.grid(axis='y', alpha=0.75)**: This adds a grid to our plot, specifically for the y-axis (axis='y'). alpha=0.75 makes the grid lines slightly transparent, so they don't overpower the data bars.

# %% [markdown]
# # ***Example 3: Daily Temperature Readings***
#
# **Scenario**: A meteorologist wants to visualize the frequency of different temperature ranges recorded over a month.

# %%
import matplotlib.pyplot as plt
import numpy as np

# Generating 30 random daily temperatures in Celsius (e.g., for a month)
daily_temperatures = np.random.normal(loc=25, scale=5, size = 40).round(1) # Normal distribution around 25°C

plt.hist(daily_temperatures, bins=8, color='skyblue', alpha=0.7) # Specify number of bins, color, and transparency
plt.title("Frequency of Daily Temperatures (Celsius)")
plt.xlabel("Temperature Range (°C)")
plt.ylabel("Number of Days")
plt.grid(axis='y', linestyle='--', alpha=0.6) # Add a dashed grid
plt.show()

# %% [markdown]
#  * **np.random.normal(loc=25, scale=5, size=30).round(1)**: This generates 30 random numbers from a normal distribution. loc=25 means the average temperature is around 25°C, and scale=5 indicates how spread out the temperatures are. .round(1) rounds the numbers to one decimal place.
#
# * **plt.hist(daily_temperatures, bins=8, color='skyblue', alpha=0.7)**: Instead of specifying exact bin edges, we can just tell Matplotlib how many bins we want (bins=8). It will then automatically divide the data into 8 equal-width bins. color='skyblue' sets the color of the bars, and alpha=0.7 makes them slightly transparent (0 is fully transparent, 1 is fully opaque).
#
# * **plt.grid(axis='y', linestyle='--', alpha=0.6)**: We're adding a grid again, but this time with a linestyle='--' which makes the grid lines dashed.

# %% [markdown]
# # ***Example 4 : Heights Distribution***

# %%
import matplotlib.pyplot as plt
import numpy as np

# Heights of 12 people in centimeters
heights = [160, 165, 170, 172, 168, 175, 163, 180, 170, 167 , 160 , 160]

# Step 1: Configure figure size for better visibility
plt.figure(figsize=(8, 5))

# Step 2: Plot histogram with better visual settings
plt.hist(
    heights,
    bins=5,                      # Reasonable number of bins for 10 data points
    color='skyblue',             # Soothing color
    edgecolor='black',           # Clear bar boundaries
    rwidth=1                   # Bar width ratio (makes bars slightly separate)
)

# Step 3: Add plot details
plt.title('Distribution of Heights of 10 People', fontsize=14)
plt.xlabel('Height (cm)', fontsize=12)
plt.ylabel('Number of People', fontsize=12)

# Step 4: Enable gridlines only on y-axis for clarity
plt.grid(axis='y', alpha=0.7, linestyle='--')

# Step 5: Display plot
#plt.tight_layout()  # Adjusts padding to avoid clipping
plt.show()

# %% [markdown]
# # ***Example 5 : Coffee Shop Analysis***

# %%
#Now, let's look at the daily sales of a small coffee shop over a month.

import matplotlib.pyplot as plt
import numpy as np

# Simulate daily sales for 30 days
np.random.seed(42) # for reproducibility
daily_sales = np.random.normal(loc=150, scale=30, size=30) # Mean sales 150, std dev 30

plt.hist(daily_sales, bins=8, edgecolor='black', alpha=0.7) # Specify number of bins and edge color
plt.title('Daily Coffee Shop Sales Distribution')
plt.xlabel('Sales Amount ($)')
plt.ylabel('Number of Days')
plt.grid(axis='y', alpha=0.75)
plt.show()

# %% [markdown]
# **Explanation**: We're using bins=8 to divide our sales data into 8 equal intervals. edgecolor='black' makes the bars stand out, and alpha=0.7 makes them slightly transparent so you can see overlapping patterns if you had multiple histograms.

# %% [markdown]
# # ***Example 6 : Two Distribution Comparison***

# %%
#Comparing the distribution of two different sets of data on the same histogram.
#Imagine comparing the scores of two different classes on the same test.

import matplotlib.pyplot as plt
import numpy as np

# Scores for Class A
class_a_scores = np.random.normal(loc=75, scale=10, size=100)

# Scores for Class B
class_b_scores = np.random.normal(loc=80, scale=8, size=100)

plt.hist(class_a_scores, bins=10, alpha=0.5, label='Class A', color='skyblue')
plt.hist(class_b_scores, bins=10, alpha=0.5, label='Class B', color='salmon')

plt.title('Comparison of Test Scores: Class A vs. Class B')
plt.xlabel('Score')
plt.ylabel('Number of Students')
plt.legend() # Show the legend to differentiate between classes
plt.grid(axis='y', alpha=0.75)
plt.show()

# %% [markdown]
# **Explanation**: By plotting two histograms with alpha=0.5 (transparency), we can easily see where the distributions overlap and where they differ. Class B seems to have slightly higher scores on average.

# %% [markdown]
# # ***2. Bar Chart: Comparing Categories***
#
# A bar chart is used to compare quantities across different categories. Imagine comparing the sales of different products, or the number of students in different classes. Each bar represents a category, and the height (or length) of the bar shows its value.
#
# **Real-Life Scenario**: You are managing a school cafeteria and want to see which food items were most popular last week.
#
# # ***Matplotlib Function***: `plt.bar(x, y)`
#
# **Parameters**:
#
# **x**: A list or array of categories (e.g., names of food items).
#
# **y**: A list or array of numerical values corresponding to each category (e.g., sales quantity).
#
# **Examples:**
#
# # ***Example 1: Top Selling Products***
#
# **Scenario**: A small shop wants to quickly see which of its five products sold the most units last month.

# %%
import matplotlib.pyplot as plt

products = ['T-shirt', 'Jeans', 'Shoes', 'Hat', 'Socks'] # Categories (product names)
sales = [150, 80, 120, 50, 100] # Corresponding sales quantities

plt.bar(products, sales) # Create a bar chart
plt.title("Monthly Sales by Product")
plt.xlabel("Product")
plt.ylabel("Units Sold")
plt.show()

# %% [markdown]
# **products = [...]:** This list contains the names of our categories (the x-values).
#
# **sales = [...]:** This list contains the numerical values for each category (the y-values). The order must match the products list.
#
# **plt.bar(products, sales)**: This command draws a bar for each product, with the height of the bar representing its sales.

# %% [markdown]
# # ***Example 2: Website Traffic by Source***
#
# **Scenario**: A digital marketer wants to compare the number of visitors coming from different sources (Google, Social Media, Direct, Email).

# %%
import matplotlib.pyplot as plt

traffic_sources = ['Google', 'Social Media', 'Direct', 'Email']
visitors = [5000, 3500, 2000, 1500]

plt.figure(figsize=(8, 5)) # Set the size of the figure
plt.bar(traffic_sources, visitors, color=['blue', 'orange', 'green', 'red']) # Assign specific colors to bars
plt.title("Website Visitors by Traffic Source", fontsize=14)
plt.xlabel("Traffic Source", fontsize=12)
plt.ylabel("Number of Visitors", fontsize=12)
plt.grid(axis='y', linestyle='--', alpha=0.7) # Add a horizontal grid
plt.xticks(rotation=15) # Rotate x-axis labels slightly for readability
plt.show()

# %% [markdown]
# **plt.figure(figsize=(8, 5))**: This creates a new figure (plot window) with a specified width of 8 inches and a height of 5 inches. This is useful for controlling the overall size of your plot.
#
# **color=['blue', 'orange', 'green', 'red']**: Here, we provide a list of colors. Matplotlib will apply these colors to the bars in the order they appear in the list.
#
# **plt.xticks(rotation=15)**: Rotates the labels on the x-axis by 15 degrees. This is helpful if your labels are long and might overlap.

# %% [markdown]
# # ***Example 3: Student Enrollment in Different Departments***
#
# **Scenario**: A university registrar wants to visualize the number of students enrolled in various academic departments.

# %%
import matplotlib.pyplot as plt

departments = ['Computer Science', 'Electrical Eng.', 'Mechanical Eng.', 'Civil Eng.', 'Biology']
enrollment = [450, 380, 320, 280, 200]

plt.bar(departments, enrollment, color='orange', edgecolor='black', alpha=0.8)
plt.title("Student Enrollment by Department", fontsize=15)
plt.xlabel("Department", fontsize=11)
plt.ylabel("Number of Students", fontsize=11)
plt.ylim(0, 500) # Set the y-axis limit
plt.grid(axis='y', linestyle=':', alpha=0.6)
plt.xticks(rotation=30, ha='left') # Rotate and align x-axis labels
plt.show()

# %% [markdown]
# **color='lightcoral', edgecolor='black', alpha=0.8**: We set a single color for all bars, add a black edge, and make them slightly transparent.
#
# **plt.ylim(0, 500)**: This explicitly sets the minimum and maximum values for the y-axis. This is useful for providing a consistent scale across multiple plots or to ensure all bars are visible.
#
# **plt.xticks(rotation=30, ha='right')**: Rotates the x-axis labels by 30 degrees and aligns them to the right of their tick marks (ha='right' stands for horizontal alignment).

# %% [markdown]
# # ***Example 4: Monthly Expense Breakdown***
#
# **Scenario**: An individual wants to see their monthly expenses categorized (rent, food, transport, entertainment, utilities).

# %%
import matplotlib.pyplot as plt

categories = ['Rent', 'Food', 'Transport', 'Entertainment', 'Utilities']
expenses = [1200, 450, 200, 300, 180]

fig, ax = plt.subplots(figsize=(9, 6))

bars = ax.bar(categories, expenses, color='teal', width=0.7, edgecolor='darkcyan', linewidth=5)

ax.set_title("Monthly Expense Breakdown", fontsize=16)
ax.set_xlabel("Expense Category", fontsize=12)
ax.set_ylabel("Amount (USD)", fontsize=12)

ax.set_ylim(0, 1400) # Set y-axis limit explicitly

# Add value labels on top of each bar
for bar in bars:
    yval = bar.get_height()
    ax.text(bar.get_x() + bar.get_width()/2, yval + 20, f'${yval:,.0f}', ha='center', va='bottom', fontsize=10)

ax.grid(axis='y', linestyle='--', alpha=0.5)
plt.tight_layout()
plt.show()

# %% [markdown]
# **fig, ax = plt.subplots(figsize=(9, 6))**: Again, using subplots for more control.
#
# **bars = ax.bar(...)**: We store the returned BarContainer object in the bars variable. This allows us to iterate through individual bars.
#
# **width=0.7**: This controls the width of the bars. A value of 1 would mean bars touch each other, 0.7 makes them narrower.
#
# **for bar in bars:**: This loop iterates through each Rectangle object representing a bar.
#
# **bar.get_height()**: Gets the height of the current bar (its y-value).
#
# **bar.get_x() + bar.get_width()/2**: Calculates the x-coordinate for placing the text label in the center of the bar.
#
# **yval + 20**: Places the text slightly above the bar.
#
# **f'${yval:,.0f}'**: This is an f-string for formatted output. :, .0f formats the number yval with commas as thousands separators and no decimal places, and we add a dollar sign.
#
# **ha='center', va='bottom'**: Ensures the text is centered horizontally and aligned to the bottom of its vertical position.

# %% [markdown]
# # ***3. Pie Chart: Showing Parts of a Whole***
#
# A pie chart is like slicing a pizza. It's used to show the proportion or percentage of different categories that make up a whole. Each slice represents a category, and the size of the slice corresponds to its percentage of the total.
#
# **Real-Life Scenario**: You want to see how different categories contribute to your monthly budget (e.g., how much goes to housing, food, transportation, etc.).
#
# # ***Matplotlib Function: `plt.pie(values, labels=labels)`***
#
# **Parameters**:
#
# **values**: A list or array of numerical values representing the size of each slice.
#
# **labels**: A list of strings corresponding to the names of each slice.
#
# **Examples**:
#
# # ***Example 1: Monthly Budget Allocation***
#
# **Scenario**: You want to visualize how your $2000 monthly income is divided among different expenses

# %%
import matplotlib.pyplot as plt

expenses_values = [800, 400, 200, 150, 450] # Amounts for each expense
expense_labels = ['Rent', 'Food', 'Transport', 'Utilities', 'Savings'] # Names of expenses

plt.pie(expenses_values, labels=expense_labels) # Create a pie chart
plt.title("Monthly Budget Allocation")
plt.axis('equal') # Ensures that pie is drawn as a circle (important for pie charts)
plt.show()

# %% [markdown]
# **expenses_values = [...]**: These are the numerical contributions of each category.
#
# **expense_labels = [...]**: These are the labels for each slice.
#
# **plt.pie(expenses_values, labels=expense_labels)**: This draws the pie chart. Matplotlib automatically calculates the percentage for each slice based on its value relative to the total.
#
# **plt.axis('equal')**: This is crucial for pie charts! It makes sure the x and y axes have the same scaling, so the pie looks like a perfect circle, not an ellipse.

# %% [markdown]
# # ***Example 2: Favorite Fruit Survey***
#
# **Scenario**: A survey was conducted asking students about their favorite fruit. You want to see the proportion of votes for each fruit.

# %%
import matplotlib.pyplot as plt

fruit_votes = [120, 90, 70, 50, 30] # Number of votes for each fruit
fruits = ['Apple', 'Banana', 'Orange', 'Grapes', 'Mango']
colors = ['lightcoral', 'gold', 'lightskyblue', 'lightgreen', 'plum'] # Custom colors

plt.figure(figsize=(7, 7)) # Adjust figure size for better visual
plt.pie(fruit_votes, labels=fruits, colors=colors, autopct='%1.1f%%', startangle=90) # Add percentage and start angle
plt.title("Favorite Fruit Survey Results", fontsize=15)
plt.axis('equal')   #equal, off, scaled
plt.show()

# %% [markdown]
# **colors = [...]**: A list of specific colors for each slice.
#
# **plt.figure(figsize=(7, 7))**: Sets the figure size to make the pie chart visually appealing.
#
# **autopct='%1.1f%%**': This is a very useful parameter! It formats the percentage values directly on the slices.
#
# **%**: Marks the start of a format specifier.
#
# **1.1f**: Means format as a floating-point number with one digit before the decimal and one digit after.
#
# **%%**: Displays a literal '%' sign.
#
# **startangle=90**: Rotates the start of the first slice to 90 degrees (top of the circle). This often makes the chart look more balanced.

# %% [markdown]
# # ***Example 3: Market Share of Smartphone Brands***
#
# **Scenario**: A tech analyst wants to show the market share of different smartphone brands in a particular quarter.

# %%
import matplotlib.pyplot as plt

market_share = [35, 25, 15, 10, 15] # Percentages
brands = ['Samsung', 'Apple', 'Xiaomi', 'Oppo', 'Others']
explode = (0.1, 0, 0, 0, 0) # "Explode" the first slice (Samsung)

plt.figure(figsize=(8, 8))
plt.pie(market_share, labels=brands, autopct='%.1f%%', startangle=140,
        explode=explode, shadow=True) # Add explode and shadow
plt.title("Smartphone Market Share (Q2 2024)", fontsize=16)
plt.axis('equal')
plt.show()

# %% [markdown]
# **explode = (0.1, 0, 0, 0, 0)**: This creates a "slice" effect where one or more slices are slightly pulled away from the center of the pie. The values in the tuple correspond to the distance each slice is exploded (0 means no explosion). Here, Samsung's slice is exploded by 0.1.
#
# **shadow=True**: Adds a subtle shadow beneath the pie chart, giving it a 3D effect.

# %% [markdown]
# # ***4. Line Chart: Showing Trends Over Time***
#
# A line chart is your go-to visualization for showing how something changes over a continuous period, usually time. Think of tracking stock prices, temperature fluctuations, or website visitors day by day. Each point represents a measurement at a specific time, and these points are connected by lines to show the trend.
#
# **Real-Life Scenario**: You are tracking the daily temperature in your city over a week to observe weather patterns.
#
# # ***Matplotlib Function: `plt.plot(x, y)`***
#
# **Parameters**:
#
# **x**: A list or array of values for the horizontal axis (usually time or an ordered sequence).
#
# **y**: A list or array of numerical values for the vertical axis, corresponding to each x value.
#
# **Examples**:
#
# # ***Example 1: Daily Stock Price***
#
# **Scenario**: You want to see how the closing price of a particular stock changed over five trading days.

# %%
import matplotlib.pyplot as plt

days = ['Mon', 'Tue', 'Wed', 'Thu', 'Fri'] # Days of the week (x-axis)
stock_price = [100, 102, 98, 105, 103] # Closing price (y-axis)

plt.plot(days, stock_price) # Create a line chart
plt.title("Stock Price Trend Over 5 Days")
plt.xlabel("Day of the Week")
plt.ylabel("Stock Price (USD)")
plt.grid(True) # Add a grid to the plot
plt.show()

# %% [markdown]
# **days = [...]**: The x-axis data, representing a sequence (days).
#
# **stock_price = [...]:** The y-axis data, representing the value at each corresponding day.
#
# **plt.plot(days, stock_price):** Connects the points (days[i], stock_price[i]) with lines.
#
# **plt.grid(True)**: Adds a grid to the background of the plot, making it easier to read values.

# %% [markdown]
# # ***Example 2: Website Traffic Over a Month***
#
# **Scenario**: A website administrator wants to see the trend of daily unique visitors over a 30-day period.

# %%
import matplotlib.pyplot as plt
import numpy as np

# Generate 30 days of unique visitor data
days = np.arange(1, 31) # Days from 1 to 30
visitors = np.random.randint(1000, 5000, 30) + np.linspace(0, 1000, 30) # Adding a slight upward trend

plt.figure(figsize=(10, 6)) # Larger figure size
plt.plot(days, visitors, marker='o', linestyle='-', color='purple', linewidth=2) # Add markers, line style, color
plt.title("Daily Unique Website Visitors (Last 30 Days)", fontsize=15)
plt.xlabel("Day of Month", fontsize=12)
plt.ylabel("Number of Visitors", fontsize=12)
plt.xticks(np.arange(1, 31, 5)) # Show ticks every 5 days
plt.grid(True, linestyle=':', alpha=0.7) # Dotted grid
plt.show()

# %% [markdown]
# **days = np.arange(1, 31)**: Creates an array of numbers from 1 to 30 using NumPy, representing the days.
#
# **visitors = np.random.randint(...) + np.linspace(...)**: Generates random visitor numbers but adds a linspace component to simulate a general upward trend over the month.
#
# **marker='o'**: Adds circular markers at each data point.
#
# **linestyle='-'**: Sets the line style to solid (this is the default, but explicitly stated here). Other options include -- (dashed), : (dotted), -. (dash-dot).
#
# **color='purple**': Sets the color of the line.
#
# **linewidth=2**: Makes the line thicker.
#
# **plt.xticks(np.arange(1, 31, 5))**: Controls which x-axis ticks are displayed, showing them every 5 days for clarity.

# %% [markdown]
# # ***Example 3: Company Revenue Growth***
#
# **Scenario**: A startup wants to visualize its quarterly revenue growth over the past two years.

# %%
import matplotlib.pyplot as plt
import numpy as np

quarters = ['Q1 2023', 'Q2 2023', 'Q3 2023', 'Q4 2023',
            'Q1 2024', 'Q2 2024', 'Q3 2024', 'Q4 2024']
revenue = [1.2, 1.5, 1.8, 2.3, 2.8, 3.5, 4.0, 4.8] # Revenue in millions USD

plt.figure(figsize=(12, 7))
plt.plot(quarters, revenue, marker='^', linestyle='--', color='darkgreen', markersize=8, markeredgecolor='black')
plt.title("Company Quarterly Revenue Growth (Millions USD)", fontsize=16, fontweight='bold')
plt.xlabel("Quarter", fontsize=12)
plt.ylabel("Revenue (Millions USD)", fontsize=12)
plt.ylim(0, 5.5) # Set Y-axis limits for better visualization
plt.grid(True, axis='y', linestyle='-', alpha=0.3) # Horizontal grid lines

# Add text labels for revenue on each point
for i, r in enumerate(revenue):
    plt.text(quarters[i], r + 0.15, f'${r:.1f}M', ha='center', va='bottom', fontsize=9)

plt.show()

# %% [markdown]
# **marker='^'**: Uses triangular markers for data points.
#
# **linestyle='--'**: Uses a dashed line.
#
# **markersize=8**: Sets the size of the markers.
#
# **markeredgecolor='black'**: Adds a black edge to the markers.
#
# **plt.ylim(0, 5.5)**: Manually sets the y-axis limits.
#
# **for i, r in enumerate(revenue):**: Loops through the revenue data to add text labels.
#
# **plt.text(...)**: Adds text to specific coordinates on the plot. ha='center', va='bottom' centers the text horizontally and aligns it to the bottom vertically relative to the point.

# %% [markdown]
# # ***Example 4: Comparison of Two Product Sales***
#
# **Scenario:** A retail manager wants to compare the monthly sales trends of two different products over six months on the same chart.

# %%
import matplotlib.pyplot as plt
import numpy as np

months = ['Jan', 'Feb', 'Mar', 'Apr', 'May', 'Jun']
product_A_sales = [150, 165, 170, 185, 190, 200]
product_B_sales = [120, 130, 145, 140, 155, 160]

fig, ax = plt.subplots(figsize=(10, 6))

ax.plot(months, product_A_sales, label='Product A', color='royalblue', marker='o', linestyle='-', linewidth=2)
ax.plot(months, product_B_sales, label='Product B', color='firebrick', marker='s', linestyle='--', linewidth=2)

ax.set_title("Monthly Sales Comparison: Product A vs. Product B", fontsize=16)
ax.set_xlabel("Month", fontsize=12)
ax.set_ylabel("Sales Units", fontsize=12)
ax.grid(True, linestyle='--', alpha=0.5)

ax.legend(loc='upper left', fontsize=10) # Add a legend to distinguish lines
plt.show()

# %% [markdown]
# **ax.plot(...)**: We call plot twice on the same ax object to draw two different lines on the same graph.
#
# **label='Product A', label='Product B'**: The label parameter is crucial when you have multiple lines. It provides the text that will appear in the legend.
#
# **ax.legend(loc='upper left', fontsize=10)**: This command displays the legend using the label parameters provided in the plot calls. loc='upper left' positions the legend in the upper left corner of the plot.

# %% [markdown]
# # ***5. Scatter Plot: Showing Relationships***
# A scatter plot is like drawing dots on a graph to see if there's a relationship between two numerical variables. Each dot represents one data point, and its position is determined by its values on the x and y axes. For example, you might use it to see if there's a connection between hours studied and exam scores, or advertising spending and sales.
#
# ***Real-Life Scenario***: You want to investigate if there's a relationship between the amount of fertilizer used and crop yield.
#
# # ***Matplotlib Function: `plt.scatter(x, y)`***
#
# **Parameters**:
#
# **x**: A list or array of numerical values for the horizontal axis.
#
# **y**: A list or array of numerical values for the vertical axis, corresponding to each x value.
#
# **Examples**:
#
# # **Example 1: Study Hours vs. Exam Scores**
#
# **Scenario**: A teacher wants to see if students who study more tend to get higher exam scores.

# %%
import matplotlib.pyplot as plt

study_hours = [2, 3, 4, 5, 6, 7, 8, 9, 10] # Hours studied
exam_scores = [60, 65, 70, 75, 80, 85, 90, 95, 100] # Corresponding exam scores

plt.scatter(study_hours, exam_scores) # Create a scatter plot
plt.title("Study Hours vs. Exam Scores")
plt.xlabel("Hours Studied")
plt.ylabel("Exam Score (%)")
plt.grid(True)
plt.show()

# %% [markdown]
# **study_hours = [...], exam_scores = [...]:** Our two numerical variables.
#
# **plt.scatter(study_hours, exam_scores):** Each pair (study_hours[i], exam_scores[i]) becomes a single point on the plot.

# %% [markdown]
# # ***Example 2: Advertising Spend vs. Sales***
#
# **Scenario**: A marketing team wants to see if increasing advertising spending leads to higher sales.

# %%
import matplotlib.pyplot as plt
import numpy as np

# Generating some sample data with a positive correlation
ad_spend = np.random.rand(50) * 1000 # Random ad spend between 0 and 1000
sales = 500 + ad_spend * 0.8 + np.random.randn(50) * 50 # Sales with some noise, correlated to ad spend

plt.figure(figsize=(9, 6))
plt.scatter(ad_spend, sales, color='teal', alpha=0.7, edgecolors='black', s=50) # Customize markers
plt.title("Advertising Spend vs. Sales Revenue", fontsize=15)
plt.xlabel("Advertising Spend (USD)", fontsize=12)
plt.ylabel("Sales Revenue (USD)", fontsize=12)
plt.grid(True, linestyle='--', alpha=0.6)
plt.show()

# %% [markdown]
# np.random.rand(50) * 1000: **bold text** Generates 50 random numbers between 0 and 1 (then scales them to 1000).
#
# **sales = 500 + ad_spend * 0.8 + np.random.randn(50) * 50:** This creates sales data that generally increases with ad_spend (the * 0.8 part) and adds some random "noise" (np.random.randn(50) * 50) to make it look more realistic.
#
# **alpha=0.7:** Makes the points slightly transparent, which is useful if many points overlap.
#
# **edgecolors='black'**: Adds a black border to each scatter point.
#
# **s=50**: Sets the size of the markers (points).

# %% [markdown]
# # ***Example 3: Student Height vs. Weight***
#
# **Scenario**: A health researcher wants to plot student heights against their weights to observe any correlation.

# %%
import matplotlib.pyplot as plt
import numpy as np

# Generate correlated height and weight data
heights_cm = np.random.normal(loc=170, scale=10, size=100) # Mean 170cm, std 10cm
weights_kg = (heights_cm * 0.6) - 30 + np.random.normal(loc=0, scale=5, size=100) # Correlated with noise

plt.figure(figsize=(8, 8))
plt.scatter(heights_cm, weights_kg, c='forestgreen', s=70, marker='X', alpha=0.8) # Different marker style and color
plt.title("Student Height vs. Weight", fontsize=15)
plt.xlabel("Height (cm)", fontsize=12)
plt.ylabel("Weight (kg)", fontsize=12)
plt.grid(True, linestyle='-', alpha=0.2) # Light grid
plt.show()

# %% [markdown]
# **np.random.normal(...):** Generates data from a normal distribution.
#
# **weights_kg = (heights_cm * 0.6) - 30 + ...:** This formula creates a positive correlation between height and weight.
#
# **c='forestgreen'**: Sets the color of the markers.
#
# **marker='X'**: Uses 'X' shaped markers. Other options include o (circle), s (square), ^ (triangle up), d (diamond), etc.

# %% [markdown]
# # ***Customization: Making Your Plots Look Good***
# Just like an artist uses different colors and adds details to their painting, we can customize our Matplotlib plots to make them more informative and visually appealing.
#
# # ***1. Colors: `color='__'`***
# You can change the color of bars, lines, or points using the color parameter. You can use common color names (like 'red', 'blue', 'green', 'purple'), hexadecimal codes (like '#FF5733'), or even RGB tuples.
#
# **Example:**
#
# # ***`plt.hist(data, color='skyblue')`***
#
# # ***`plt.bar(x, y, color='lightgreen')`***
#
# # ***`plt.plot(x, y, color='darkorange')`***
#
# # ***`plt.scatter(x, y, color='#4CAF50')`***

# %% [markdown]
# # ***2. Legends: plt.legend()***
# When you have multiple lines or data series on the same plot (especially useful in line and scatter plots), a legend helps viewers identify what each line or set of points represents.
#
# **How to use it:**
#
# When you call a plotting function (like `plt.plot()` or `plt.scatter()`), add a `label='Your Label'` parameter.
#
# After all your plotting commands for that figure, call `plt.legend()`.

# %%
import matplotlib.pyplot as plt

x = [1, 2, 3, 4, 5]
y1 = [10, 12, 15, 13, 16]
y2 = [8, 10, 11, 9, 14]

plt.plot(x, y1, label='Series A', color='blue') # Add label for first line
plt.plot(x, y2, label='Series B', color='red', linestyle='--') # Add label for second line

plt.title("Comparison of Series A and B")
plt.xlabel("X-axis")
plt.ylabel("Y-axis")
plt.legend() # Display the legend using the labels defined above
plt.grid(True)
plt.show()

# %% [markdown]
# **label='Series A' and label='Series B'**: These strings are what will appear in your legend.
#
# **plt.legend()**: This command looks for all the label arguments in the plt.plot (or plt.scatter, plt.bar) calls and creates a legend with those labels and corresponding line/marker styles. You can also specify its location, e.g., plt.legend(loc='upper right').

# %% [markdown]
# # ***SUMMARY***
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# # ***Fun Practice Game: Complete the Syntax!***
# **Objective**: Fill in the blanks ___ to generate the desired plot. Each problem is a standalone snippet.

# %%
#Desired Output: A histogram showing a normal distribution of 1000 random numbers, with 20 bins,
#blue bars, and a title "Random Number Distribution".

import matplotlib.pyplot as plt
import numpy as np

data = np.random.randn(1000) # Generate 1000 random numbers from a standard normal distribution

plt.hist(data, bins = 20, color='blue')
plt.title("Random Number Distribution")
plt.xlabel("Value")
plt.ylabel("Frequency")
plt.show()

# %% [markdown]
# ```
# import matplotlib.pyplot as plt
# import numpy as np
#
# data = np.random.randn(1000)
#
# plt.hist(data, bins=20, color='skyblue') # data, number of bins, color
# plt.title("Random Number Distribution") # Title of the plot
# plt.xlabel("Value")
# plt.ylabel("Frequency")
# plt.show()
# ```

# %%
#Desired Output: A bar chart comparing the scores of three students: Alice (90), Bob (85), Carol (92). Bars should be green.

import matplotlib.pyplot as plt

students = ['Alice', 'Bob', 'Carol']
scores = [90, 85, 92]

plt.bar(students,scores , color='green')
plt.title("Students Marks Distribution")
plt.xlabel("Student")
plt.ylabel("Score")
plt.show()

# %% [markdown]
# ```
# import matplotlib.pyplot as plt
#
# students = ['Alice', 'Bob', 'Carol']
# scores = [90, 85, 92]
#
# plt.bar(students, scores, color='lightgreen') # x-axis (categories), y-axis (values), color
# plt.title("Student Scores") # Title of the plot
# plt.xlabel("Student")
# plt.ylabel("Score")
# plt.show()
# ```

# %%
#Desired Output: A pie chart showing the distribution of expenses: Rent (500), Food (200), Transport (100).
#Percentages should be displayed on slices.

import matplotlib.pyplot as plt

expense_amounts = [500, 200, 100]
expense_categories = ['Rent', 'Food', 'Transport']

plt.pie(expense_amounts, labels=expense_categories, autopct='%1.1f%%')
plt.title("Expense Distribution")
plt.axis('equal')
plt.show()

# %% [markdown]
# ```
# import matplotlib.pyplot as plt
#
# expense_amounts = [500, 200, 100]
# expense_categories = ['Rent', 'Food', 'Transport']
#
# plt.pie(expense_amounts, labels=expense_categories, autopct='%1.1f%%') # values, labels, percentage format
# plt.title("Expense Distribution") # Title of the plot
# plt.axis('equal')
# plt.show()
# ```

# %%
#Desired Output: A line chart comparing two trends: Trend A (values: 10, 12, 15, 13) and
#Trend B (values: 8, 11, 10, 14) over 4 points. Both lines should be on the same graph, and a legend should be present.

import matplotlib.pyplot as plt

x_values = [1, 2, 3, 4]
trend_A = [10, 12, 15, 13]
trend_B = [8, 11, 10, 14]

plt.plot(x_values, trend_A, label='Trend A', color='blue')
plt.plot(x_values, trend_B, label='Trend B', color='green', linestyle='--')
plt.title("Comparison of Trends")
plt.xlabel("Point")
plt.ylabel("Value")
plt.legend()
plt.show()

# %% [markdown]
# ```
# import matplotlib.pyplot as plt
#
# x_values = [1, 2, 3, 4]
# trend_A = [10, 12, 15, 13]
# trend_B = [8, 11, 10, 14]
#
# plt.plot(x_values, trend_A, label='Trend A', color='blue') # x, y, label, color
# plt.plot(x_values, trend_B, label='Trend B', color='red', linestyle='--') # x, y, label, color, linestyle
# plt.title("Trend Comparison") # Title of the plot
# plt.xlabel("Point")
# plt.ylabel("Value")
# plt.legend()
# plt.show()
# ```

# %% [markdown]
# # ***Spot the Bug Game!***
# **Objective**: Find and fix the single bug in each code snippet that prevents it from generating the desired output or causes an error.

# %%
import matplotlib.pyplot as plt

ages = [18, 20, 25, 30, 22, 28, 35, 40, 25, 20]

plt.hist(ages)
plt.title("Age Distribution")
plt.show()

# %% [markdown]
# **Explanation of Bug**: plt.set_title() is used when you have an Axes object (e.g., ax.set_title()). When using plt. directly, you should use plt.title().

# %%
import matplotlib.pyplot as plt

product_names = ['Product X', 'Product Y']
sales_units = [100, 75]
colors_list = ['blue', 'green']

plt.bar(product_names, sales_units, color=colors_list)
plt.title("Product Sales")
plt.show()

# %% [markdown]
# **Explanation of Bug**: When providing a list of colors, the number of colors must match the number of bars. Here, there are two products but only one color in colors_list.

# %%
import matplotlib.pyplot as plt

data_points = [10, 20, 7]
labels = ['A', 'B', 'C']

plt.pie(data_points, labels=labels, autopct='%1.1f%%')
plt.axis('equal')
plt.show()

# %% [markdown]
# **Explanation of Bug**: The autopct format string %.0f means "format as a floating-point number with zero decimal places". However, autopct receives the percentage as a decimal (e.g., 0.1 for 10%). To display it as an actual percentage, you need %% at the end to include the literal '%' symbol.

# %% [markdown]
# # ***Homework Exercises for Students***
# These exercises will help you practice and apply the concepts of basic plots and customization in Matplotlib. Remember to explain your code with comments!
#
# **Hint for all exercises**: Start by importing matplotlib.pyplot as plt and numpy as np (if you need to generate data). Always include plt.title(), plt.xlabel(), plt.ylabel(), and plt.show().
#
# # ***Exercise 1: Age Distribution of a Community (Histogram)***
#
# **Scenario**: You are part of a community project and want to understand the age groups of residents.
#
# **Task**: Create a histogram of the following ages: [5, 10, 12, 18, 22, 25, 28, 30, 32, 35, 40, 45, 50, 55, 60, 65, 70, 75, 80, 85]
#
# **Customization**:
#
# * Set the title to "Community Age Distribution".
#
# * Label the x-axis "Age Group" and the y-axis "Number of Residents".
#
# * Use bins=5 to group the ages into 5 bins.
#
# * Make the bars green.
#
# # **Exercise 2: Monthly Rainfall in a City (Bar Chart)**
#
# **Scenario**: A local weather station wants to display the rainfall for the first six months of the year.
#
# **Task**: Create a bar chart for the following data:
#
# Months: ['Jan', 'Feb', 'Mar', 'Apr', 'May', 'Jun']
#
# Rainfall (mm): [70, 55, 80, 95, 60, 45]
#
# **Customization**:
#
# * Set the title to "Monthly Rainfall (First Half)".
#
# * Label the x-axis "Month" and the y-axis "Rainfall (mm)".
#
# * Make the bars lightblue.
#
# * Add a horizontal grid (plt.grid(axis='y')).
#
# # **Exercise 3: Student's Study Time Allocation (Pie Chart)**
#
# **Scenario**: A student wants to analyze how they spend their 16 waking hours (assuming 8 hours of sleep).
#
# **Task**: Create a pie chart for the following activities and hours:
#
# Activities: ['Classes', 'Study', 'Part-time Job', 'Hobbies', 'Meals/Breaks']
#
# Hours: [5, 4, 3, 2, 2] (Total 16 hours)
#
# **Customization:**
#
# * Set the title to "Daily Study Time Allocation".
#
# * Display percentages on the slices (autopct).
#
# * Ensure the pie chart is a perfect circle (plt.axis('equal')).
#
# * Choose your own set of distinct colors for each slice.

# %% [markdown]
# # **Exercise 4: Company's Profit Trend Over Years (Line Chart)**
#
# **Scenario**: A company's CEO wants to see how their annual profit has changed over the last 7 years.
#
# **Task**: Create a line chart:
#
# Years: [2018, 2019, 2020, 2021, 2022, 2023, 2024]
#
# Profit (in millions USD): [10, 12, 11, 15, 18, 20, 22]
#
# **Customization**:
#
# * Set the title to "Annual Profit Trend".
#
# * Label the x-axis "Year" and the y-axis "Profit (Millions USD)".
#
# * Add red circular marker='o' at each data point.
#
# * Use a dashed line style (linestyle='--').
#
# * Add a grid to the plot (plt.grid(True)).

# %% [markdown]
# # ***Exercise 5: Customer Satisfaction vs. Support Tickets (Scatter Plot)***
#
# **Scenario**: A customer service manager wants to see if there's a relationship between a customer's satisfaction rating (1-5) and the number of support tickets they've opened in the last month.
#
# **Task**: Create a scatter plot for the following simulated data (you can extend this data if you wish):
#
# Satisfaction Ratings: [4, 3, 5, 2, 4, 1, 5, 3, 2, 4, 5, 1, 3, 4, 2]
#
# Support Tickets Opened: [1, 2, 0, 3, 1, 5, 0, 2, 4, 1, 0, 6, 3, 1, 4]
#
# **Customization**:
#
# * Set the title to "Customer Satisfaction vs. Support Tickets".
#
# * Label the x-axis "Satisfaction Rating (1-5)" and the y-axis "Number of Support Tickets".
#
# * Make the points orange.
#
# * Add a grid to the plot.
#
# # ***Exercise 6: Combined Plot: Daily Sales and Advertising Spend (Line Plot with Two Lines and Legend)***
#
# **Scenario**: A marketing analyst wants to see how daily sales track with daily advertising spending over a week.
#
# **Task**: Create a single line plot with two lines: one for sales and one for advertising spend.
#
# **Data**:
#
# Days: ['Day 1', 'Day 2', 'Day 3', 'Day 4', 'Day 5', 'Day 6', 'Day 7']
#
# Daily Sales (Units): [100, 120, 110, 130, 140, 125, 150]
#
# Daily Ad Spend (USD): [50, 60, 55, 65, 70, 60, 75]
#
# **Customization**:
#
# * Set the title to "Daily Sales vs. Advertising Spend".
#
# * Label the x-axis "Day" and the y-axis "Units/USD".
#
# * Give meaningful labels to each line for the legend.
#
# * Make sales line blue and ad spend line purple.
#
# * Add a legend to the plot.
#
# * Add a grid.

# %% [markdown]
# ![image.png](data:image/png;base64,...)
#
# # **ANY DOUBTS ?!**
